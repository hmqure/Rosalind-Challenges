# %%
seq1 = "..."
seq2 = "..."

def CountPointMutations(seq1, seq2):
    
    hamm = 0

    for num in range(len(seq1)):   #if nt at same index doesnt match, add 1 to counter
            if seq1[num] != seq2[num]:
                hamm += 1
            else:
                hamm += 0

    return(hamm)

# %%
print(CountPointMutations(seq1, seq2))
# Out:
# 460
